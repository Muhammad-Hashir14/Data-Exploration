# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('Downloads/StudentsPerformance.csv')

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.index = np.arange(1,1001)

# %%
data
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 1     female        group B           bachelor's degree      standard
# 2     female        group C                some college      standard
# 3     female        group B             master's degree      standard
# 4       male        group A          associate's degree  free/reduced
# 5       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 996   female        group E             master's degree      standard
# 997     male        group C                 high school  free/reduced
# 998   female        group C                 high school  free/reduced
# 999   female        group D                some college      standard
# 1000  female        group D                some college  free/reduced
#
#      test preparation course  math score  reading score  writing score
# ...

# %%
programming = np.random.randint(0,100,(1000,1))

# %%
programming.shape
# Out:
# (1000, 1)

# %%
programming = pd.DataFrame(programming)

# %%
programming
# Out:
#       0
# 0    22
# 1    91
# 2    40
# 3    12
# 4    66
# ..   ..
# 995  69
# 996  42
# 997  93
# 998  16
# 999  46
#
# [1000 rows x 1 columns]

# %%
theory = np.random.randint(0,99,(1000))

# %%
theory = pd.DataFrame(theory)

# %%
theory
# Out:
#       0
# 0    98
# 1    32
# 2    62
# 3    57
# 4    15
# ..   ..
# 995  43
# 996  34
# 997  42
# 998  47
# 999  87
#
# [1000 rows x 1 columns]

# %%
df = pd.concat([data,programming,theory] ,axis = 1)

# %%
df
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 1     female        group B           bachelor's degree      standard
# 2     female        group C                some college      standard
# 3     female        group B             master's degree      standard
# 4       male        group A          associate's degree  free/reduced
# 5       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997     male        group C                 high school  free/reduced
# 998   female        group C                 high school  free/reduced
# 999   female        group D                some college      standard
# 1000  female        group D                some college  free/reduced
# 0        NaN            NaN                         NaN           NaN
#
#      test preparation course  math score  reading score  writing score     0  \
# ...

# %%
df.drop(0,axis = 0, inplace=True)

# %%
df
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 1     female        group B           bachelor's degree      standard
# 2     female        group C                some college      standard
# 3     female        group B             master's degree      standard
# 4       male        group A          associate's degree  free/reduced
# 5       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 996   female        group E             master's degree      standard
# 997     male        group C                 high school  free/reduced
# 998   female        group C                 high school  free/reduced
# 999   female        group D                some college      standard
# 1000  female        group D                some college  free/reduced
#
#      test preparation course  math score  reading score  writing score     0  \
# ...

# %%
df.columns = ['gender','race/ethnicity','parental level of education','lunch','test preparation course','math score','reading score','writing score','Programming score','Theory score']

# %%
df
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 1     female        group B           bachelor's degree      standard
# 2     female        group C                some college      standard
# 3     female        group B             master's degree      standard
# 4       male        group A          associate's degree  free/reduced
# 5       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 996   female        group E             master's degree      standard
# 997     male        group C                 high school  free/reduced
# 998   female        group C                 high school  free/reduced
# 999   female        group D                some college      standard
# 1000  female        group D                some college  free/reduced
#
#      test preparation course  math score  reading score  writing score  \
# ...

# %%
df['math score'].isnull().sum()
# Out:
# 0

# %%
df['reading score'].isnull().sum()
# Out:
# 0

# %%
df['reading score'].isnull().sum()
# Out:
# 0

# %%
df['Programming score'].isnull().sum()
df[df['Programming score'].isnull()]
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 1000  female        group D                some college  free/reduced
#
#      test preparation course  math score  reading score  writing score  \
# 1000                    none        77.0           86.0           86.0
#
#       Programming score  Theory score
# 1000                NaN           NaN

# %%
df['Theory score'].isnull().sum()
df[df['Programming score'].isnull()]
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 1000  female        group D                some college  free/reduced
#
#      test preparation course  math score  reading score  writing score  \
# 1000                    none        77.0           86.0           86.0
#
#       Programming score  Theory score
# 1000                NaN           NaN

# %%
df['Programming score'].fillna(df['Programming score'].mean(),inplace=True)

# %%
df
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 1     female        group B           bachelor's degree      standard
# 2     female        group C                some college      standard
# 3     female        group B             master's degree      standard
# 4       male        group A          associate's degree  free/reduced
# 5       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 996   female        group E             master's degree      standard
# 997     male        group C                 high school  free/reduced
# 998   female        group C                 high school  free/reduced
# 999   female        group D                some college      standard
# 1000  female        group D                some college  free/reduced
#
#      test preparation course  math score  reading score  writing score  \
# ...

# %%
df['Theory score'].mean()
df['Theory score'].fillna(df['Theory score'].mean(),inplace = True)
df
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 1     female        group B           bachelor's degree      standard
# 2     female        group C                some college      standard
# 3     female        group B             master's degree      standard
# 4       male        group A          associate's degree  free/reduced
# 5       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 996   female        group E             master's degree      standard
# 997     male        group C                 high school  free/reduced
# 998   female        group C                 high school  free/reduced
# 999   female        group D                some college      standard
# 1000  female        group D                some college  free/reduced
#
#      test preparation course  math score  reading score  writing score  \
# ...

# %%
def calculate(s1 , s2 ,s3, s4 , s5):
    addit = s1 + s2 + s3 + s4 + s5
    per = addit/500 * 100
    grade = ''
    if per > 80 and per <= 100:
        grade = 'A+'
    elif per > 70 and per <= 80:
        grade = 'A'
    elif per > 60 and per <= 70:
        grade = 'B'
    elif per > 50 and per <=60:
        grade = 'C'
    elif per > 40 and per <= 50:
        grade = 'D'
    else:
        grade = 'F'
    return addit , per , grade

# %%
df[['Obtained Marks','Percentage','Grade']] = df[['math score','reading score','writing score','Programming score','Theory score']].apply(lambda x:calculate(x[0],x[1],x[2],x[3],x[4]) ,axis=1,result_type='expand')

# %%
df
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 1     female        group B           bachelor's degree      standard
# 2     female        group C                some college      standard
# 3     female        group B             master's degree      standard
# 4       male        group A          associate's degree  free/reduced
# 5       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 996   female        group E             master's degree      standard
# 997     male        group C                 high school  free/reduced
# 998   female        group C                 high school  free/reduced
# 999   female        group D                some college      standard
# 1000  female        group D                some college  free/reduced
#
#      test preparation course  math score  reading score  writing score  \
# ...

# %%
pd.DataFrame(df.groupby('Grade'))
# Out:
#     0                                                  1
# 0   A       gender race/ethnicity parental level of e...
# 1  A+       gender race/ethnicity parental level of e...
# 2   B        gender race/ethnicity parental level of ...
# 3   C       gender race/ethnicity parental level of e...
# 4   D       gender race/ethnicity parental level of e...
# 5   F       gender race/ethnicity parental level of e...

# %%
Aplus_students = pd.DataFrame(df.groupby('Grade'))[1].values[1]
Aplus_students
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 17     male        group C                 high school      standard
# 35     male        group E                some college      standard
# 105    male        group C                some college      standard
# 107  female        group D             master's degree      standard
# 123  female        group C                some college      standard
# 156  female        group C                some college      standard
# 230  female        group C                some college      standard
# 234    male        group E            some high school      standard
# 240    male        group C          associate's degree      standard
# 264  female        group E                 high school      standard
# 289    male        group B           bachelor's degree  free/reduced
# 374  female        group D                some college      standard
# 398  female        group C          associate's degree      standard
# ...

# %%
A_students = pd.DataFrame(df.groupby('Grade'))[1].values[0]
A_students
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 6    female        group B          associate's degree      standard
# 7    female        group B                some college      standard
# 9      male        group D                 high school  free/reduced
# 21     male        group D                 high school      standard
# 36     male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 985  female        group C            some high school      standard
# 988    male        group E            some high school      standard
# 991    male        group E                 high school  free/reduced
# 996  female        group E             master's degree      standard
# 999  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
B_students = pd.DataFrame(df.groupby('Grade'))[1].values[2]
B_students
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 1     female        group B           bachelor's degree      standard
# 2     female        group C                some college      standard
# 3     female        group B             master's degree      standard
# 5       male        group C                some college      standard
# 13    female        group B                 high school      standard
# ...      ...            ...                         ...           ...
# 990   female        group D                some college  free/reduced
# 993   female        group D          associate's degree  free/reduced
# 994   female        group D           bachelor's degree  free/reduced
# 997     male        group C                 high school  free/reduced
# 1000  female        group D                some college  free/reduced
#
#      test preparation course  math score  reading score  writing score  \
# ...

# %%
C_students = pd.DataFrame(df.groupby('Grade'))[1].values[3]
C_students
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 14     male        group A                some college      standard
# 15   female        group A             master's degree      standard
# 16   female        group C            some high school      standard
# 19     male        group C             master's degree  free/reduced
# 20   female        group C          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 979    male        group D                 high school      standard
# 987  female        group C          associate's degree      standard
# 992  female        group B            some high school      standard
# 995    male        group A                 high school      standard
# 998  female        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
D_students = pd.DataFrame(df.groupby('Grade'))[1].values[4]
D_students
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 4      male        group A          associate's degree  free/reduced
# 10   female        group B                 high school  free/reduced
# 11     male        group C          associate's degree      standard
# 12     male        group D          associate's degree      standard
# 18   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 956    male        group E          associate's degree      standard
# 961  female        group A                some college      standard
# 968    male        group C                some college      standard
# 974  female        group D                some college  free/reduced
# 977    male        group B                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
F_students = pd.DataFrame(df.groupby('Grade'))[1].values[5]
F_students
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 8      male        group B                some college  free/reduced
# 51     male        group E                some college      standard
# 56   female        group C                 high school  free/reduced
# 58     male        group D          associate's degree      standard
# 60   female        group C            some high school  free/reduced
# 75     male        group C            some high school      standard
# 77     male        group E            some high school      standard
# 132    male        group C            some high school  free/reduced
# 144    male        group A                 high school      standard
# 185    male        group C            some high school  free/reduced
# 212    male        group C                some college  free/reduced
# 251    male        group A            some high school      standard
# 299    male        group C                 high school  free/reduced
# ...

# %%
print('Students got highest',df[['Percentage']].max())
df[df['Percentage'] == 90.8]
# Out:
# Students got highest Percentage    90.8
# dtype: float64
#     gender race/ethnicity parental level of education     lunch  \
# 917   male        group E           bachelor's degree  standard
#
#     test preparation course  math score  reading score  writing score  \
# 917               completed       100.0          100.0          100.0
#
#      Programming score  Theory score  Obtained Marks  Percentage Grade
# 917               61.0          93.0           454.0        90.8    A+

# %%
print('Student got lowest',df[['Percentage']].min())
df[df['Percentage'] ==23.799999999999997 ]
# Out:
# Student got lowest Percentage    23.8
# dtype: float64
#      gender race/ethnicity parental level of education         lunch  \
# 981  female        group B                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 981                    none         8.0           24.0           23.0
#
#      Programming score  Theory score  Obtained Marks  Percentage Grade
# 981                3.0          61.0           119.0        23.8     F

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   float64
#  6   reading score                1000 non-null   float64
#  7   writing score                1000 non-null   float64
#  8   Programming score            1000 non-null   float64
#  9   Theory score                 1000 non-null   float64
#  10  Obtained Marks               1000 non-null   float64
#  11  Percentage                   1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#        math score  reading score  writing score  Programming score  \
# count  1000.00000    1000.000000    1000.000000        1000.000000
# mean     66.08900      69.169000      68.054000          50.333333
# std      15.16308      14.600192      15.195657          28.560457
# min       0.00000      17.000000      10.000000           0.000000
# 25%      57.00000      59.000000      57.750000          25.000000
# 50%      66.00000      70.000000      69.000000          51.000000
# 75%      77.00000      79.000000      79.000000          75.000000
# max     100.00000     100.000000     100.000000          99.000000
#
#        Theory score  Obtained Marks   Percentage
# count   1000.000000     1000.000000  1000.000000
# mean      48.799800      302.445133    60.489027
# std       28.736558       58.734035    11.746807
# min        0.000000      119.000000    23.800000
# 25%       22.000000      261.000000    52.200000
# 50%       49.000000      304.000000    60.800000
# ...

# %%
print("Total A+ grade students",len(Aplus_students))
print("Total A grade students",len(A_students))
print("Total B grade students",len(B_students))
print("Total C grade students",len(C_students))
print("Total D grade students",len(D_students))
print("Total F grade students",len(F_students))
# Out:
# Total A+ grade students 47
# Total A grade students 163
# Total B grade students 306
# Total C grade students 291
# Total D grade students 151
# Total F grade students 42

# %%
df.groupby('Grade').sum()
# Out:
#        math score  reading score  writing score  Programming score  \
# Grade
# A         12413.0        12982.0        12859.0       11406.000000
# A+         4055.0         4255.0         4209.0        3523.000000
# B         21699.0        22732.0        22487.0       16290.333333
# C         18124.0        18848.0        18585.0       13252.000000
# D          8079.0         8504.0         8152.0        4738.000000
# F          1719.0         1848.0         1762.0        1124.000000
#
#        Theory score  Obtained Marks    Percentage
# Grade
# A        10996.0000    60656.000000  12131.200000
# A+        3613.0000    19655.000000   3931.000000
# B        16355.7998    99564.133133  19912.826627
# C        11765.0000    80574.000000  16114.800000
# D         4949.0000    34422.000000   6884.400000
# F         1121.0000     7574.000000   1514.800000

# %%
p =df.groupby('Grade').count()
p
# Out:
#        gender  race/ethnicity  parental level of education  lunch  \
# Grade
# A         163             163                          163    163
# A+         47              47                           47     47
# B         306             306                          306    306
# C         291             291                          291    291
# D         151             151                          151    151
# F          42              42                           42     42
#
#        test preparation course  math score  reading score  writing score  \
# Grade
# A                          163         163            163            163
# A+                          47          47             47             47
# B                          306         306            306            306
# C                          291         291            291            291
# D                          151         151            151            151
# ...
